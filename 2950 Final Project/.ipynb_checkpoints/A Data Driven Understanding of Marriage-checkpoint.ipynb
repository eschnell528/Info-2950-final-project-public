# %%
#this is the section of the project that people see
#make a note about the data mining process - I was told that I would get more credit for this

#import the csv

#IDEAS FOR ANALYSIS
#regression of years vs different emotional scores
#clustering & classification??? - gender of writer & one of the scores or male/female word ratio

#I could data mine other topics & compare them across the attributes that I collected as well


#questions: 
# 1)how has the percetion of marriage changed over time[regression using variables and ratio]
# 2)does one gender seem to dominate marriage [cluster ratio of gendered words based on gender of author]
# 3)is marriage good or bad [clustering good/bad/where marriage fits in]

#Tasts
    #generating the data: 1)clean nrc, 2)generate scores, 3)write to csv, 4)automate using loop, 5)gather data & run 

    #analyzing the data: 1)import csv, 2)import graph & statistical packages, 3)run the analysis for current data set
    #analysis includes 1)change in scores over time(regression), 2)male/female word ratio based on gender of author(clustering?),

    #iterative design: 1)obtain new data sets using a similar data entry procedure (1 positive ex:happiness, 1 bad ex:war)
    # 2)add the marriage data into the classification and see which set it fits into
    
#Time: clean nrc (2), generate scores (2), write to csv (1), automate using loop (1), gather data & run (4),
# import csv & packages (1), scores over time (1), clustering(1)

# %% [markdown]
# Info 2950 | Phase 2 | Evan Schnell | 10/20/22
#
# Data Format
# Each row of the enclosed dataframe consists of the title of the book, the author’s gender, the estimated year of publication, and the number of occurrences of words that fit into the categories: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, and trust.
#
# Research Questions
# Q1) Are the categories provided in the lexicon (anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, and trust) generally independent or do they interact with each other?
# Q2) How has the perception of marriage changed over time?
# Q3) What is the effect of the author’s gender on his or her perception of marriage?
#
# Plan for Answering the Research Questions
# Question 1
# - I will determine how the categories (anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, and trust) are related to each other by identifying the principal components of the data using Principal Component Analysis (PCA), a common unsupervised dimensionality reduction algorithm. I may perform this analysis separately on the data gathered from books written by males and females.
# - Principal components are indices that are linear combinations of the original data categories. Understanding how the principal components are created for my data set will help me identify how variables are correlated within a higher dimensional data set. I hope to compare the results I obtain from my principal axes with results from a covariance matrix as a sanity check.
# - Dimensional reduction techniques allow the user to account for more variables at the cost of losing some of the variance enclosed within the data. I hope to leverage PCA, a quantitative dimensional reduction technique, to determine what portion of the variance can be attributed to various principal axes and identify an optimal tradeoff between retained variance and the power of my tests.
#
# Question 2
# - I plan to run regressions on each of the emotional scores versus time. Based on the results of the principal axes I identify using PCA, the regressions I run in this step will likely change.
# - I plan to run data from male and female authors separately.
#
# Question 3
# - How I attempt to answer this question will depend on the results I get from parts 1 and 2.
# - As of right now, I plan to run logistic regressions like what we did on homework 4.
#
# How I obtained a lexicon for scoring
# - I found the
#
# How I Obtained the Data
#
#
# I generated each row in my dataframe by comparing
#
#
#
#
#
#
#
#
#
# Data Source
#
# Lexicon Source
#
# Limitations (Effect on People & Data Gaps)
#
# Categories: anger, anticipation, disgust, fear, joy, negative, positive, sadness, surprise, trust
